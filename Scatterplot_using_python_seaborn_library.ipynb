# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dm-office-sales/dm_office_sales.csv

# %%
#import numpy as np # linear algebra
#import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Base library for seaborn library
import matplotlib.pyplot as plt

# For all kinds of plots
import seaborn as sns

# %%
# To read the entire tutorial. Kindly visit the below link.
# To read the entire tutorial. Kindly visit the below link.
# To read the entire tutorial. Kindly visit the below link.


# https://notepub.io/notes/programming-languages/python-seaborn-for-data-visualization/python-seaborn-for-data-visualization-scatter-plots/


# Importing data.
# index_col = 0 means, Set index 0 as first column.
# na_values = ["??","????"] replace missing values with NaN values.

# This dataset contains both numerical and categorical variables which will help us to learn the uses of seaborn library.
office_data = pd.read_csv("/kaggle/input/dm-office-sales/dm_office_sales.csv",index_col=0,na_values=["??","????"])
office_data
# Out:
#                    level of education  training level  work experience  \
# division
# printers                 some college               2                6
# printers           associate's degree               2               10
# peripherals               high school               0                9
# office supplies    associate's degree               2                5
# office supplies           high school               1                5
# ...                               ...             ...              ...
# computer hardware  associate's degree               1                1
# computer software  associate's degree               1                0
# peripherals        associate's degree               2                8
# peripherals        associate's degree               2                3
# computer hardware        some college               0                9
#
#                    salary   sales
# division
# printers            91684  372302
# ...

# %%
# Checking for missing values
office_data.isnull()
# Out:
#                    level of education  training level  work experience  \
# division
# printers                        False           False            False
# printers                        False           False            False
# peripherals                     False           False            False
# office supplies                 False           False            False
# office supplies                 False           False            False
# ...                               ...             ...              ...
# computer hardware               False           False            False
# computer software               False           False            False
# peripherals                     False           False            False
# peripherals                     False           False            False
# computer hardware               False           False            False
#
#                    salary  sales
# division
# printers            False  False
# ...

# %%
office_data.isna().sum()
office_data.isnull().sum()
# Data set is perfect. No missing values.
# Out:
# level of education    0
# training level        0
# work experience       0
# salary                0
# sales                 0
# dtype: int64

# %%
office_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, printers to computer hardware
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   level of education  1000 non-null   object
#  1   training level      1000 non-null   int64
#  2   work experience     1000 non-null   int64
#  3   salary              1000 non-null   int64
#  4   sales               1000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 46.9+ KB

# %%
office_data.head()
# Out:
#                  level of education  training level  work experience  salary  \
# division
# printers               some college               2                6   91684
# printers         associate's degree               2               10  119679
# peripherals             high school               0                9   82045
# office supplies  associate's degree               2                5   92949
# office supplies         high school               1                5   71280
#
#                   sales
# division
# printers         372302
# printers         495660
# peripherals      320453
# office supplies  377148
# office supplies  312802

# %%
plt.figure(figsize=(14,5),dpi=100)
sns.scatterplot(x='salary', y='sales',data=office_data)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(10,3),dpi=200)
sns.scatterplot(x='salary', y='sales',data=office_data, hue="training level")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(10,3),dpi=200)
sns.scatterplot(x='salary', y='sales',data=office_data, hue="level of education")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(10,3),dpi=200)
sns.scatterplot(x='salary', y='work experience',data=office_data)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='work experience'>

# %%
plt.figure(figsize=(10,3),dpi=200)
sns.scatterplot(x='salary', y='sales', hue='training level',data=office_data, palette='Set1')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(10,3),dpi=200)
sns.scatterplot(x='salary', y='sales',data=office_data, size="work experience")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(10,3),dpi=200)
sns.scatterplot(x='salary', y='sales',data=office_data, s=200, alpha=0.2)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(10,3),dpi=200)
sns.scatterplot(x='salary', y='sales',data=office_data, s=200, style="level of education")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
#sns.set_style("darkgrid")
#sns.set_context("poster")
plt.figure(figsize=(10,3),dpi=200)
sns.scatterplot(x='salary', y='sales',data=office_data,  style="level of education", hue="level of education", palette='Set1', alpha = 0.9, c=400)

#plt.savefig("plot.png")
#plt.show()
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>
